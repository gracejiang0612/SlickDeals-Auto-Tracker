# %%
import requests
from bs4 import BeautifulSoup
import time

# %%
base_url = "https://slickdeals.net/deals/?page="
all_popular_deals_info = []
for num in range(1, 6):
    my_url = base_url + str(num)
    single_page_html = requests.get(my_url).content
    single_page_doc = BeautifulSoup(single_page_html,'html.parser')
    all_deals = single_page_doc.find_all("div", class_="dealRow")  
    for deal in all_deals:
        deal_title = deal.find("div", class_="dealTitle").text.strip().split('\n')[1]
        slick_deal_url = "https://slickdeals.net" + deal.find("a", class_="track-popularDealLink bp-p-dealLink bp-c-link")["href"]
        deal_info_html = requests.get(slick_deal_url).content
        deal_info_doc = BeautifulSoup(deal_info_html,'html.parser')   
        deal_link_type_1 = deal_info_doc.find("a", class_="dealDetailsOutclickButton dealDetailsMainBlock__outclickButton")
        deal_line_type_2 = deal_info_doc.find("a", class_="seeDealButton")
        if deal_link_type_1:
            deal_link = deal_link_type_1["href"]
        elif deal_line_type_2:
            deal_link = deal_line_type_2["href"]
        else:
            deal_link = "N/A"
        deal_price = deal.find("div", class_="price").get_text(strip=True)
        posted_time = deal.find("div", class_="dealLinks").text.strip().split('\n')[0]
        rating = deal.find("div", class_="ratingCol stats").get_text(strip=True)
        activity_col = deal.find("div", class_="activityCol stats")
        views = activity_col.find("div", class_="activity").text.strip().split('\n')[0]
        comments = activity_col.find_all("div", class_="activity")[1].text.strip().split('\n')[0]
        all_popular_deals_info.append({"title": deal_title, "link": deal_link, "price": deal_price, "posted_time": posted_time, "rating": rating, "views": views, "comments": comments})

# %%
print(all_popular_deals_info)
# Out:
# [{'title': "6' Werner Aluminum Type 1 Step Ladder (250-lb Load Capacity) $39 + Free Store Pickup at Lowe's", 'link': 'https://ui.slickdeals.net/click?trd=Get%20Deal%20at%20Lowe%27s&sdtid=17969073&tid=17969073&prop=diavail-true%7Cdincp-2%7Cdinpd-8%7Cdipgavail-true&pv=65c48fe4b38511ef83dc5e54003cc3e8&au=8e0b9152dd074c8696a8fc3aa8f8db11', 'price': '$39.00', 'posted_time': 'Posted Today ', 'rating': '+6', 'views': '763 Views', 'comments': '1 Comments'}, {'title': '3-Piece Ironton Jumbo Pipe Wrench Set (14", 18", 24") $22.69 + Free Shipping', 'link': 'https://ui.slickdeals.net/click?trd=Get%20Deal%20at%20Northern%20Tool&sdtid=17969049&tid=17969049&prop=diavail-false%7Cdincp-0%7Cdinpd-0%7Cdipgavail-false&pv=66c37d06b38511efada476c1dac4b8f1&au=ae04a5b543b34edab86c6db00dbd18ef', 'price': '$22.69', 'posted_time': 'Posted Today ', 'rating': '+8', 'views': '615 Views', 'comments': '0 Comments'}, {'title': '[S&S] $5.02: 96-Oz Betty Crocker Bisquick Original Pancake & Baking Mix at Amazon', 'link': 'https://ui.slickdeals.net/click?trd=Get%20Deal%20at%20Amazon&sdtid=17964093&tid=17964093&prop=diavail-true%7Cdincp-1%7Cdinpd-8%7Cdipgavail-true&pv=679bbb8ab38511ef879402bbc7ebd4d5&au=86c688fe5f674179ab25537ece462980', 'price': '$5.02', 'posted_time': 'Posted Yesterday ', 'rating': '+6', 'views': '713 Views', 'comments': '0 Comments'}, {'title': 'Lenovo Ideacentre Mini PC Desktop: Intel Core i5-13500H, 8GB DDR4, 512GB SSD, W11P (Refurbished) $254.79 + Free Shipping @ eBay', 'link': 'https://ui.slickdeals.net/click?trd=Get%20Deal%20at%
# 95  Squier Classic Vibe '60s Precision Bass Limite...
# 96  Blackstone Outdoor Tabletop Propane Pizza Oven...
# 97  Clinique: 40% Off Serums & Eye Creams + 30% Of...
# 98  5'x7' Anti-Slip Backing Washable Oriental Area...
# 99  $53.99*: Vikings: The Complete Series (Blu-ray...
#
#                                                  link    price  \
# 0   https://ui.slickdeals.net/click?trd=Get%20Deal...   $39.00
# 1   https://ui.slickdeals.net/click?trd=Get%20Deal...   $22.69
# 2   https://ui.slickdeals.net/click?trd=Get%20Deal...    $5.02
# 3   https://ui.slickdeals.net/click?trd=Get%20Deal...  $254.79
# 4   https://ui.slickdeals.net/click?trd=Get%20Deal...    $6.98
# ..                                                ...      ...
# 95  https://ui.slickdeals.net/click?trd=Get%20Deal...  $320.00
# 96  https://ui.slickdeals.net/click?trd=Get%20Deal...  $147.00
# 97  https://ui.slickdeals.net/click?trd=Get%20Deal...
# 98  https://ui.slickdeals.net/click?trd=Get%20Deal...   $45.99
# 99  https://ui.slickdeals.net/click?trd=Get%20Deal...   $53.99
#
#            posted_time rating         views     comments
# 0        Posted Today      +6     763 Views   1 Comments
# 1        Posted Today      +8     615 Views   0 Comments
# 2    Posted Yesterday      +6     713 Views   0 Comments
# 3        Posted Today      +5   2,033 Views   5 Comments
# 4        Posted Today      +6   1,492 Views   4 Comments
# ..                 ...    ...           ...          ...
# 95  Posted 12-02-2024     +10   1,835 Views   3 Comments
# 96  Posted 11-29-2024     +16  14,645 Views  20 Comments
# 97  Posted 12-02-2024      +9   3,614 Views   2 Comments
# 98  Posted 12-03-2024     +14   8,757 Views  18 Comments
# 99  Posted 12-02-2024     +12   1,954 Views   5 Comments
#
# [100 rows x 7 columns]

# %%
output_file = 'popular_deals.csv'
deals_df.to_csv(output_file, index=False, encoding='utf-8')

print(f"Data saved to {output_file}")
# Out:
# Data saved to popular_deals.csv

# %%
for num in range(1, 6):
    my_url = base_url + str(num)
    single_page_html = requests.get(my_url).content
    single_page_doc = BeautifulSoup(single_page_html,'html.parser')
    all_deals = single_page_doc.find_all("div", class_="dealRow")

# %%
for deal in all_deals:
    time.sleep(2)
    deal_title = deal.find("div", class_="dealTitle").text.strip().split('\n')[1]
    slick_deal_url = "https://slickdeals.net" + deal.find("a", class_="track-popularDealLink bp-p-dealLink bp-c-link")["href"]
    deal_info_html = requests.get(slick_deal_url).content
    deal_info_doc = BeautifulSoup(deal_info_html,'html.parser')
    deal_link = deal_info_doc.find("a", class_="dealDetailsOutclickButton dealDetailsMainBlock__outclickButton")["href"]
    deal_price = deal.find("div", class_="price").get_text(strip=True)
    posted_time = deal.find("div", class_="dealLinks").text.strip().split('\n')[0]
    rating = deal.find("div", class_="ratingCol stats").get_text(strip=True)
    activity_col = deal.find("div", class_="activityCol stats")
    views = activity_col.find("div", class_="activity").text.strip().split('\n')[0]
    comments = activity_col.find_all("div", class_="activity")[1].text.strip().split('\n')[0]
    all_popular_deals_info.append({"title": deal_title, "link": deal_link, "price": deal_price, "posted_time": posted_time, "rating": rating, "views": views, "comments": comments})
