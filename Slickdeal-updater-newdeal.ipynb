# %%
import requests
from bs4 import BeautifulSoup
import time

# %%
base_url = "https://slickdeals.net/deals/?page="
all_popular_deals_info = []
for num in range(1, 6):
    my_url = base_url + str(num)
    single_page_html = requests.get(my_url).content
    single_page_doc = BeautifulSoup(single_page_html,'html.parser')
    all_deals = single_page_doc.find_all("div", class_="dealRow")  
    for deal in all_deals:
        deal_title = deal.find("div", class_="dealTitle").text.strip().split('\n')[1]
        slick_deal_url = "https://slickdeals.net" + deal.find("a", class_="track-popularDealLink bp-p-dealLink bp-c-link")["href"]
        deal_info_html = requests.get(slick_deal_url).content
        deal_info_doc = BeautifulSoup(deal_info_html,'html.parser')   
        deal_link_type_1 = deal_info_doc.find("a", class_="dealDetailsOutclickButton dealDetailsMainBlock__outclickButton")
        deal_line_type_2 = deal_info_doc.find("a", class_="seeDealButton")
        if deal_link_type_1:
            deal_link = deal_link_type_1["href"]
        elif deal_line_type_2:
            deal_link = deal_line_type_2["href"]
        else:
            deal_link = "N/A"
        deal_price = deal.find("div", class_="price").get_text(strip=True)
        posted_time = deal.find("div", class_="dealLinks").text.strip().split('\n')[0]
        rating = deal.find("div", class_="ratingCol stats").get_text(strip=True)
        activity_col = deal.find("div", class_="activityCol stats")
        views = activity_col.find("div", class_="activity").text.strip().split('\n')[0]
        comments = activity_col.find_all("div", class_="activity")[1].text.strip().split('\n')[0]
        all_popular_deals_info.append({"title": deal_title, "link": deal_link, "price": deal_price, "posted_time": posted_time, "rating": rating, "views": views, "comments": comments})

# %%
print(all_popular_deals_info)
# Out:
# [{'title': "Refurb Citizen Eco-Drive Men's Chronograph Titanium Watch 44MM - $124.09 at Officialwatchdeals via eBay", 'link': 'https://ui.slickdeals.net/click?trd=Get%20Deal%20at%20eBay&sdtid=17975490&tid=17975490&prop=diavail-false%7Cdincp-0%7Cdinpd-0%7Cdipgavail-false&pv=c8bfaaa4b5a411ef9df4fe6f7c8c1c28&au=26f7682f2b7f46db9749828ce7fdefdb', 'price': '$124.09', 'posted_time': 'Posted Today ', 'rating': '+4', 'views': '476 Views', 'comments': '1 Comments'}, {'title': 'DeWALT Adjustable Creeper Shop Stool with Casters at Tractor Supply - $80.00', 'link': 'https://ui.slickdeals.net/click?trd=Get%20Deal%20at%20Retailer&sdtid=17974314&tid=17974314&prop=diavail-false%7Cdincp-0%7Cdinpd-0%7Cdipgavail-false&pv=c9f09208b5a411efb30d1214bd03f198&au=dc30f9b66beb453c947cac19df5eb0d3', 'price': '$79.99', 'posted_time': 'Posted Yesterday ', 'rating': '+6', 'views': '1,742 Views', 'comments': '5 Comments'}, {'title': "LEGO Animal Crossing: K.K.'s Concert at the Plaza (77052) and Julian's Birthday Party (77046) Bundle - $49.97 - Costco (online)", 'link': 'https://ui.slickdeals.net/click?trd=Get%20Deal%20at%20
# %%
import pandas as pd
deals_df = pd.DataFrame(all_popular_deals_info)
deals_df
# Out:
#                                                 title  \
# 0   Refurb Citizen Eco-Drive Men's Chronograph Tit...
# 1   DeWALT Adjustable Creeper Shop Stool with Cast...
# 2   LEGO Animal Crossing: K.K.'s Concert at the Pl...
# 3   6-qt Imusa Enamel Stock Pot (Blue) $10.97 + Fr...
# 4   adidas Men's Own The Run Shirt (White/Reflecti...
# ..                                                ...
# 95  $5.99: 4.5-Oz Lindt Holiday Teddy Bear Chocola...
# 96  Minisforum BD790i MoDT (Mobile on Desktop) Min...
# 97  **Starts 12/17** T-Mobile T-Life App Offer: Cl...
# 98  Women's Cozy Socks: Shine Cat Cozy Slipper Soc...
# 99                            Epic Games: Delta Force
#
#                                                  link    price  \
# 0   https://ui.slickdeals.net/click?trd=Get%20Deal...  $124.09
# 1   https://ui.slickdeals.net/click?trd=Get%20Deal...   $79.99
# 2   https://ui.slickdeals.net/click?trd=Get%20Deal...   $49.97
# 3   https://ui.slickdeals.net/click?trd=Get%20Deal...   $10.97
# 4   https://ui.slickdeals.net/click?trd=Get%20Deal...    $7.00
# ..                                                ...      ...
# 95  https://ui.slickdeals.net/click?trd=Get%20Deal...    $5.99
# 96  https://ui.slickdeals.net/click?trd=Get%20Deal...  $429.00
# 97  https://ui.slickdeals.net/click?trd=Get%20Deal...    $5.00
# 98  https://ui.slickdeals.net/click?trd=Get%20Deal...    $3.19
# 99  https://ui.slickdeals.net/click?trd=Get%20Deal...     FREE
#
#            posted_time rating         views     comments
# 0        Posted Today      +4     476 Views   1 Comments
# 1    Posted Yesterday      +6   1,742 Views   5 Comments
# 2    Posted Yesterday      +7   2,561 Views   4 Comments
# 3        Posted Today      +4     768 Views   2 Comments
# 4    Posted Yesterday      +4   3,692 Views   9 Comments
# ..                 ...    ...           ...          ...
# 95  Posted 12-04-2024     +19  10,052 Views  11 Comments
# 96  Posted 12-03-2024     +10  12,823 Views  27 Comments
# 97  Posted 12-04-2024     +20  10,348 Views  18 Comments
# 98  Posted 12-04-2024      +6   3,822 Views   2 Comments
# 99  Posted 12-04-2024    +217  52,893 Views  55 Comments
#
# [100 rows x 7 columns]

# %%
output_file = 'popular_deals.csv'
deals_df.to_csv(output_file, index=False, encoding='utf-8')

print(f"Data saved to {output_file}")
# Out:
# Data saved to popular_deals.csv
